# %%
import simnibs
from simnibs import sim_struct, run_simnibs

# %% [markdown]
# [Paper](https://linkinghub.elsevier.com/retrieve/pii/S1053811919307748)

# %% [markdown]
# ## Leadfield Calculations

# %%
tdcs_lf = sim_struct.TDCSLEADFIELD()

# %%
tdcs_lf.fnamehead = '../simnibs/simnibs_examples/ernie/ernie.msh'

# %%
tdcs_lf.pathfem = 'leadfield' # output directory

# %%
tdcs_lf.solver_options = 'pardiso'

# %%
run_simnibs(tdcs_lf)
# Out:
# [ simnibs ]INFO: Running simulations in the directory: /home/mark/Desktop/Insai/insai-tes-simulations/notebooks/leadfield
# [ simnibs ]INFO: Head Mesh: /home/mark/Desktop/Insai/insai-tes-simulations/simnibs/simnibs_examples/ernie/ernie.msh
# [ simnibs ]INFO: Subject Path: /home/mark/Desktop/Insai/insai-tes-simulations/simnibs/simnibs_examples/ernie/m2m_ernie
# [ simnibs ]INFO: Simulation Folder: /home/mark/Desktop/Insai/insai-tes-simulations/notebooks/leadfield
# [ simnibs ]INFO: EEG Cap: /home/mark/Desktop/Insai/insai-tes-simulations/simnibs/simnibs_examples/ernie/m2m_ernie/eeg_positions/EEG10-10_UI_Jurak_2007.csv
# [ simnibs ]INFO: Placing Electrodes
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ -1.2267 -15.8119 115.9564]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 1
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-6.2721e-02  9.0261e+01  3.7521e+01]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 2
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [29.1761 86.7724 34.0518]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 3
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-56.4449  68.8931  29.6802]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 4
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-35.0114  76.533   57.5491]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 5
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 0.2769 81.8794 69.8227]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 6
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [35.9274 78.3291 57.7061]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 7
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [54.7937 69.2823 28.893 ]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 8
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-71.8209  46.2463  -8.7493]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 9
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-70.5204  41.6059  25.6347]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 10
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-62.9365  46.6589  50.9397]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 11
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-49.3257  52.2534  73.0298]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 12
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-27.8081  55.156   88.5437]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 13
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [3.5509e-02 5.7780e+01 9.5247e+01]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 14
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [27.7873 57.0234 87.7332]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 15
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [49.6485 53.714  72.1523]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 16
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [62.7368 48.4008 50.4106]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 17
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [69.4804 43.3974 25.6274]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 18
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [68.1774 45.2843 -8.6117]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 19
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-78.0004  16.1176 -12.486 ]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 20
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-78.042   12.2255  22.3996]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 21
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-73.5261  15.3299  54.0134]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 22
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-59.6422  18.9683  80.4377]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 23
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-34.3803  21.9799 102.0834]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 24
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ -0.6419  22.9204 110.095 ]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 25
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 32.7695  23.3163 102.223 ]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 26
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [59.0836 20.0273 81.2717]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 27
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [73.3858 18.0043 53.6766]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 28
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [76.5994 13.7182 22.3256]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 29
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 76.9998  17.6726 -11.7703]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 30
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-80.5333 -12.3106 -15.171 ]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 31
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-80.9592 -16.1745  20.4698]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 32
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-81.3466 -16.7038  50.8672]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 33
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-67.1582 -16.5999  82.7626]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 34
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-39.7759 -16.6413 106.8743]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 35
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-29.9784  86.3478  34.2277]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 36
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 36.6165 -15.327  106.8313]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 37
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 64.3218 -15.3767  82.6648]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 38
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 78.5765 -15.6032  51.7398]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 39
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 77.8661 -14.7546  21.1394]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 40
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 76.4763 -12.0941 -14.468 ]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 41
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-87.556  -45.6142 -18.7333]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 42
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-82.6766 -45.7596  17.7928]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 43
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-78.9912 -49.3503  49.2742]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 44
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-66.1061 -52.9477  80.4007]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 45
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-38.8917 -56.9152 104.2741]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 46
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ -2.5031 -57.818  114.038 ]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 47
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 34.5727 -56.2241 104.818 ]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 48
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 61.2638 -52.1441  80.7577]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 49
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 73.405  -48.0459  50.2314]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 50
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 78.1874 -45.0892  18.5931]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 51
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 82.2632 -44.7616 -18.499 ]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 52
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-69.3983 -69.0787 -18.0508]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 53
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-74.4144 -74.3982  16.5753]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 54
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-68.4295 -80.9129  41.6064]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 55
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-54.6583 -85.6073  64.8355]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 56
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-32.6129 -90.5142  81.9463]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 57
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ -3.6505 -94.313   89.4455]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 58
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 25.816  -90.3338  83.2737]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 59
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 48.7255 -84.5152  66.0984]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 60
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 62.809  -79.6758  42.178 ]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 61
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 65.5342 -72.7524  17.1063]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 62
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 64.4452 -69.4027 -17.602 ]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 63
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-54.5713 -93.6308 -19.2401]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 64
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [-55.5042 -99.4184  16.0254]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 65
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ -38.3602 -107.9504   43.5724]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 66
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [  -4.2832 -111.6835   54.3194]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 67
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [  30.4599 -106.8367   44.6177]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 68
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 48.5023 -96.4926  16.5506]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 69
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ 48.3035 -93.3868 -18.3391]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 70
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ -31.6276 -114.5621   17.6748]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 71
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [  -4.2161 -119.       20.1947]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 72
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [  24.055  -113.0555   17.4885]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 73
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [  -4.6183 -113.9203  -15.3579]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 74
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [ -30.5353 -108.29    -17.5684]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 75
# number of holes: 0
#
# [ simnibs ]INFO: Placing Electrode:
# definition: plane
# shape: ellipse
# centre: [  23.4342 -107.2289  -17.0587]
# pos_ydir: []
# dimensions: [10, 10]
# thickness:[4]
# channelnr: 76
# number of holes: 0
#
# [ simnibs ]INFO: Improving mesh quality
# [ simnibs ]INFO: Running Leadfield
# [ simnibs ]INFO: Using isotropic conductivities
# [ simnibs ]INFO: Assembling FEM Matrx
# [ simnibs ]INFO: 7.46s to assemble FEM matrix
# [ simnibs ]INFO: Running Simulation 1 out of 75
# [ simnibs ]INFO: Using solver options: pardiso
# [ simnibs ]INFO: Factorizing matrix using MKL PARDISO
# [ simnibs ]INFO: 83.57 seconds to factorize matrix
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.41 seconds to solve system
# [ simnibs ]INFO: Running Simulation 2 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 3 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 4 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 5 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 6 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 7 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 8 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 9 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 10 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 11 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 12 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 13 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 14 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 15 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 16 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 17 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 18 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 19 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 20 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 21 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 22 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 23 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 24 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 25 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 26 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 27 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 28 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 29 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 30 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 31 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 32 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 33 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 34 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 35 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 36 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 37 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 38 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 39 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 40 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 41 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 42 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 43 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 44 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 45 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 46 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 47 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 48 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 49 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 50 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 51 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 52 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 53 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 54 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 55 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 56 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 57 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 58 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 59 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 60 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 61 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 62 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 63 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 64 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 65 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 66 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 67 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 68 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 69 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 70 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 71 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.35 seconds to solve system
# [ simnibs ]INFO: Running Simulation 72 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 73 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 74 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: Running Simulation 75 out of 75
# [ simnibs ]INFO: Solving system using MKL PARDISO
# [ simnibs ]INFO: 0.34 seconds to solve system
# [ simnibs ]INFO: =====================================
# [ simnibs ]INFO: SimNIBS finished running leadfield
# [ simnibs ]INFO: Final HDF5 file:
# [ simnibs ]INFO: /home/mark/Desktop/Insai/insai-tes-simulations/notebooks/leadfield/ernie_leadfield_EEG10-10_UI_Jurak_2007.hdf5
# [ simnibs ]INFO: =====================================

# %% [markdown]
# ## Optimization

# %% [markdown]
# ### Simple Optimization

# %%
opt = simnibs.opt_struct.TDCSoptimize()

# %%
opt.leadfield_hdf = 'leadfield/ernie_leadfield_EEG10-10_UI_Jurak_2007.hdf5'

# %%
opt.name = 'optimization/single_target'

# %% [markdown]
# Maximum total current (in A)

# %%
opt.max_total_current = 2e-3

# %% [markdown]
# Maximum current at each electrode (in A)

# %%
opt.max_individual_current = 1e-3

# %% [markdown]
# Maximum number of active electrodes

# %%
opt.max_active_electrodes = 8

# %% [markdown]
# Define optimization target

# %%
target = opt.add_target()

# %%
target.positions = [-55.4, -20.7, 73.4]

# %% [markdown]
# Intensity of the electric field (in V/m)

# %%
target.intensity = 0.2

# %%
simnibs.run_simnibs(opt)
# Out:
# [ simnibs ]INFO: Optimizing
# [ simnibs ]SUMMARY: Optimization set-up
# ===========================
# Leadfield file: leadfield/ernie_leadfield_EEG10-10_UI_Jurak_2007.hdf5
# Max. total current: 0.002 (A)
# Max. individual current: 0.001 (A)
# Max. active electrodes: 8
# Name: optimization/single_target
# ----------------------
# N targets: 1
# Target 1:
# positions: [-55.4, -20.7, 73.4]
# indexes: None
# directions: normal
# radius: 2
# intensity: 0.2
# max_angle: None
# tissues: None
# ----------------------
# N avoid: 0
#
# [ simnibs ]SUMMARY:
# Optimization Summary
# =============================
# Total current: 1.99e-03 (A)
# Maximum current: 1.00e-03 (A)
# Active electrodes: 8
# Field Summary
# ----------------------------
# Peak Value (99.9 percentile): 0.18 (E)
# Mean field norm: 1.65e-02 (E)
# Focality: 50%: 8.20e+03 70%: 2.74e+03 (mm2)
# Target 1
#     Intensity specified:0.20 achieved: 0.20 (E)
#     Average angle across target: 21.1 (degrees)
#
# [ simnibs ]SUMMARY:
# =====================================
# SimNIBS finished running optimization
# Mesh file: optimization/single_target.msh
# CSV file: optimization/single_target.csv
# Summary file: optimization/single_target_summary.txt
# =====================================
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/subprocess.py", line 487, in run
#     output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command '['/home/mark/anaconda3/envs/zen_env/lib/python3.7/site-packages/simnibs/bin/linux/gmsh', '/home/mark/Desktop/Insai/insai-tes-simulations/notebooks/optimization/single_target.msh']' returned non-zero exit status 1.

# %% [markdown]
# ### Maximizing intensity

# %%
opt = simnibs.opt_struct.TDCSoptimize()

# %%
opt.leadfield_hdf = 'leadfield/ernie_leadfield_EEG10-10_UI_Jurak_2007.hdf5'

# %%
opt.name = 'optimization/single_target_max_int'

# %%
opt.max_total_current = 2e-3
opt.max_individual_current = 1e-3
opt.max_active_electrodes = 8

# %%
target = opt.add_target()

# %%
target.positions = [-55.4, -20.7, 73.4]

# %%
target.intensity = 100

# %%
simnibs.run_simnibs(opt)
# Out:
# [ simnibs ]INFO: Optimizing
# [ simnibs ]SUMMARY: Optimization set-up
# ===========================
# Leadfield file: leadfield/ernie_leadfield_EEG10-10_UI_Jurak_2007.hdf5
# Max. total current: 0.002 (A)
# Max. individual current: 0.001 (A)
# Max. active electrodes: 8
# Name: optimization/single_target_max_int
# ----------------------
# N targets: 1
# Target 1:
# positions: [-55.4, -20.7, 73.4]
# indexes: None
# directions: normal
# radius: 2
# intensity: 100
# max_angle: None
# tissues: None
# ----------------------
# N avoid: 0
#
# [ simnibs ]SUMMARY:
# Optimization Summary
# =============================
# Total current: 2.00e-03 (A)
# Maximum current: 1.00e-03 (A)
# Active electrodes: 8
# Field Summary
# ----------------------------
# Peak Value (99.9 percentile): 0.57 (E)
# Mean field norm: 2.06e-01 (E)
# Focality: 50%: 3.54e+04 70%: 3.31e+03 (mm2)
# Target 1
#     Intensity specified:100.00 achieved: 0.35 (E)
#     Average angle across target: 40.2 (degrees)
#
# [ simnibs ]SUMMARY:
# =====================================
# SimNIBS finished running optimization
# Mesh file: optimization/single_target_max_int.msh
# CSV file: optimization/single_target_max_int.csv
# Summary file: optimization/single_target_max_int_summary.txt
# =====================================
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/subprocess.py", line 487, in run
#     output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command '['/home/mark/anaconda3/envs/zen_env/lib/python3.7/site-packages/simnibs/bin/linux/gmsh', '/home/mark/Desktop/Insai/insai-tes-simulations/notebooks/optimization/single_target_max_int.msh']' returned non-zero exit status 1.

# %% [markdown]
# ### Using MNI Coordinates

# %%
opt = simnibs.opt_struct.TDCSoptimize()

# %%
opt.leadfield_hdf = 'leadfield/ernie_leadfield_EEG10-10_UI_Jurak_2007.hdf5'

# %%
opt.name = 'optimization/MNI_target'

# %%
opt.max_total_current = 2e-3

# %%
opt.max_individual_current = 1e-3

# %%
opt.max_active_electrodes = 8

# %%
target = opt.add_target()

# %% [markdown]
# Transform a set of coordinates from MNI space to subject space.

# %%
target.positions = simnibs.mni2subject_coords([-37, -21, 58], '../simnibs/simnibs_examples/ernie/m2m_ernie/')

# %%
target.intensity = 0.2

# %%
simnibs.run_simnibs(opt)
# Out:
# [ simnibs ]INFO: Optimizing
# [ simnibs ]SUMMARY: Optimization set-up
# ===========================
# Leadfield file: leadfield/ernie_leadfield_EEG10-10_UI_Jurak_2007.hdf5
# Max. total current: 0.002 (A)
# Max. individual current: 0.001 (A)
# Max. active electrodes: 8
# Name: optimization/MNI_target
# ----------------------
# N targets: 1
# Target 1:
# positions: [-38.3342 -27.2943  79.8826]
# indexes: None
# directions: normal
# radius: 2
# intensity: 0.2
# max_angle: None
# tissues: None
# ----------------------
# N avoid: 0
#
# [ simnibs ]SUMMARY:
# Optimization Summary
# =============================
# Total current: 2.00e-03 (A)
# Maximum current: 1.00e-03 (A)
# Active electrodes: 8
# Field Summary
# ----------------------------
# Peak Value (99.9 percentile): 0.25 (E)
# Mean field norm: 4.55e-02 (E)
# Focality: 50%: 1.26e+04 70%: 3.80e+03 (mm2)
# Target 1
#     Intensity specified:0.20 achieved: 0.20 (E)
#     Average angle across target: 13.5 (degrees)
#
# [ simnibs ]SUMMARY:
# =====================================
# SimNIBS finished running optimization
# Mesh file: optimization/MNI_target.msh
# CSV file: optimization/MNI_target.csv
# Summary file: optimization/MNI_target_summary.txt
# =====================================
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/subprocess.py", line 487, in run
#     output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command '['/home/mark/anaconda3/envs/zen_env/lib/python3.7/site-packages/simnibs/bin/linux/gmsh', '/home/mark/Desktop/Insai/insai-tes-simulations/notebooks/optimization/MNI_target.msh']' returned non-zero exit status 1.

# %% [markdown]
# ### Multiple targets

# %%
opt = simnibs.opt_struct.TDCSoptimize()

# %%
opt.leadfield_hdf = 'leadfield/ernie_leadfield_EEG10-10_UI_Jurak_2007.hdf5'

# %%
opt.name = 'optimization/two_targets'

# %%
opt.max_total_current = 2e-3

# %%
opt.max_individual_current = 1e-3

# %%
opt.max_active_electrodes = 8

# %% [markdown]
# Target in the left motor cortex

# %%
target_left = opt.add_target()

# %%
target_left.positions = [-34.0, -21.4, 88.5]

# %%
target_left.intensity = 0.2

# %% [markdown]
# Target in the right motor cortex

# %%
target_right = opt.add_target()

# %%
target_right.positions = [34.0, -25.5, 90.4]

# %%
target_right.intensity = -0.2

# %%
simnibs.run_simnibs(opt)
# Out:
# [ simnibs ]INFO: Optimizing
# [ simnibs ]SUMMARY: Optimization set-up
# ===========================
# Leadfield file: leadfield/ernie_leadfield_EEG10-10_UI_Jurak_2007.hdf5
# Max. total current: 0.002 (A)
# Max. individual current: 0.001 (A)
# Max. active electrodes: 8
# Name: optimization/two_targets
# ----------------------
# N targets: 2
# Target 1:
# positions: [-34.0, -21.4, 88.5]
# indexes: None
# directions: normal
# radius: 2
# intensity: 0.2
# max_angle: None
# tissues: None
# ......................
# Target 2:
# positions: [34.0, -25.5, 90.4]
# indexes: None
# directions: normal
# radius: 2
# intensity: -0.2
# max_angle: None
# tissues: None
# ----------------------
# N avoid: 0
#
# [ simnibs ]SUMMARY:
# Optimization Summary
# =============================
# Total current: 2.00e-03 (A)
# Maximum current: 1.00e-03 (A)
# Active electrodes: 8
# Field Summary
# ----------------------------
# Peak Value (99.9 percentile): 0.39 (E)
# Mean field norm: 1.25e-01 (E)
# Focality: 50%: 2.87e+04 70%: 6.12e+03 (mm2)
# Target 1
#     Intensity specified:0.20 achieved: 0.18 (E)
#     Average angle across target: 59.8 (degrees)
# Target 2
#     Intensity specified:-0.20 achieved: -0.20 (E)
#     Average angle across target: 41.0 (degrees)
#
# [ simnibs ]SUMMARY:
# =====================================
# SimNIBS finished running optimization
# Mesh file: optimization/two_targets.msh
# CSV file: optimization/two_targets.csv
# Summary file: optimization/two_targets_summary.txt
# =====================================
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/subprocess.py", line 487, in run
#     output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command '['/home/mark/anaconda3/envs/zen_env/lib/python3.7/site-packages/simnibs/bin/linux/gmsh', '/home/mark/Desktop/Insai/insai-tes-simulations/notebooks/optimization/two_targets.msh']' returned non-zero exit status 1.

# %% [markdown]
# ### Avoidance Regions

# %%
opt = simnibs.opt_struct.TDCSoptimize()

# %%
opt.leadfield_hdf = 'leadfield/ernie_leadfield_EEG10-10_UI_Jurak_2007.hdf5'

# %%
opt.name = 'optimization/avoid'

# %%
opt.max_total_current = 2e-3

# %%
opt.max_individual_current = 1e-3

# %%
opt.max_active_electrodes = 8

# %%
target = opt.add_target()

# %%
target.positions = simnibs.mni2subject_coords([-37, -21, 58], '../simnibs/simnibs_examples/ernie/m2m_ernie/')

# %%
target.intensity = 0.2

# %%
avoid = opt.add_avoid()

# %%
avoid.tissues = 1006 # corresponds to the eye surface

# %%
simnibs.run_simnibs(opt)
# Out:
# [ simnibs ]INFO: Optimizing
# [ simnibs ]SUMMARY: Optimization set-up
# ===========================
# Leadfield file: leadfield/ernie_leadfield_EEG10-10_UI_Jurak_2007.hdf5
# Max. total current: 0.002 (A)
# Max. individual current: 0.001 (A)
# Max. active electrodes: 8
# Name: optimization/avoid
# ----------------------
# N targets: 1
# Target 1:
# positions: [-38.3342 -27.2943  79.8826]
# indexes: None
# directions: normal
# radius: 2
# intensity: 0.2
# max_angle: None
# tissues: None
# ----------------------
# N avoid: 1
# Avoid 1:
# positions: None
# indexes: None
# radius: 2
# weights: 1.0e+03
# tissues: 1006
#
# [ simnibs ]SUMMARY:
# Optimization Summary
# =============================
# Total current: 2.00e-03 (A)
# Maximum current: 1.00e-03 (A)
# Active electrodes: 8
# Field Summary
# ----------------------------
# Peak Value (99.9 percentile): 0.25 (E)
# Mean field norm: 4.97e-02 (E)
# Focality: 50%: 1.28e+04 70%: 3.71e+03 (mm2)
# Target 1
#     Intensity specified:0.20 achieved: 0.20 (E)
#     Average angle across target: 13.0 (degrees)
# Avoid 1
#     Mean field norm in region: 2.75e-03 (E)
#
# [ simnibs ]SUMMARY:
# =====================================
# SimNIBS finished running optimization
# Mesh file: optimization/avoid.msh
# CSV file: optimization/avoid.csv
# Summary file: optimization/avoid_summary.txt
# =====================================
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mark/anaconda3/envs/zen_env/lib/python3.7/subprocess.py", line 487, in run
#     output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command '['/home/mark/anaconda3/envs/zen_env/lib/python3.7/site-packages/simnibs/bin/linux/gmsh', '/home/mark/Desktop/Insai/insai-tes-simulations/notebooks/optimization/avoid.msh']' returned non-zero exit status 1.
